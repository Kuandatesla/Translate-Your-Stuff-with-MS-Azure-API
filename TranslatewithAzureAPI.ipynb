# %%
import fitz  # PyMuPDF
import requests
import uuid
import os
import time

# Azure Translator API settings
key = ""  # Replace with your actual Azure Translator key
endpoint = "https://api.cognitive.microsofttranslator.com"  # Correct endpoint
location = ""  # e.g., "eastus"

# Function to extract text from a PDF
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as pdf:
        for page in pdf:
            text += page.get_text()
    return text

# Function to translate text to Portuguese using Azure Translator
def translate_to_portuguese(text):
    url = f"{endpoint}/translate"
    
    headers = {
        'Ocp-Apim-Subscription-Key': key,
        'Ocp-Apim-Subscription-Region': location,
        'Content-type': 'application/json',
        'X-ClientTraceId': str(uuid.uuid4())
    }

    translated_text = ""
    max_chunk_size = 5000
    text_chunks = [text[i:i + max_chunk_size] for i in range(0, len(text), max_chunk_size)]

    for chunk in text_chunks:
        body = [{'text': chunk}]
        
        params = {
            'api-version': '3.0',
            'to': 'pt-br'  # Translate to Brazilian Portuguese
        }

        retries = 5
        for attempt in range(retries):
            response = requests.post(url, headers=headers, params=params, json=body)
            
            if response.status_code == 200:
                translation = response.json()[0]['translations'][0]['text']
                translated_text += translation + " "  # Append translated chunk
                break  # Exit the retry loop if successful
            elif response.status_code == 429:  # Rate limit exceeded
                print("Rate limit exceeded, retrying...")
                time.sleep(2 ** attempt)  # Exponential backoff
            else:
                print(f"Translation failed for chunk: {response.status_code} - {response.text}")
                break  # Exit on other errors

    return translated_text.strip()  # Return the complete translated text

# Function to extract images from a PDF
def extract_images_from_pdf(pdf_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    with fitz.open(pdf_path) as pdf_document:
        for page_number in range(len(pdf_document)):
            page = pdf_document.load_page(page_number)
            images = page.get_images(full=True)

            for img_index, img in enumerate(images):
                xref = img[0]
                base_image = pdf_document.extract_image(xref)
                image_bytes = base_image["image"]
                image_ext = base_image["ext"]
                image_filename = f"page_{page_number + 1}_img_{img_index + 1}.{image_ext}"

                with open(os.path.join(output_folder, image_filename), "wb") as image_file:
                    image_file.write(image_bytes)

# Main function
def main():
    pdf_path = r''  # Update your PDF path here
    output_folder = r''  # Output folder for images

    # Extract and translate text
    text = extract_text_from_pdf(pdf_path)
    
    if text:
        translated_text = translate_to_portuguese(text)
        if translated_text:
            print("Translated Text:")
            print(translated_text)
        else:
            print("Translation failed or returned empty text.")
    else:
        print("No text found in the PDF.")

    # Extract images
    extract_images_from_pdf(pdf_path, output_folder)
    print(f"Images extracted to {output_folder}.")

if __name__ == "__main__":
    main()
# Out:
# Rate limit exceeded, retrying...
# Rate limit exceeded, retrying...
# Rate limit exceeded, retrying...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 102
#      99     print(f"Images extracted to {output_folder}.")
#     101 if __name__ == "__main__":
# --> 102     main()
#
# Cell In[18], line 88, in main()
#      85 text = extract_text_from_pdf(pdf_path)
#      87 if text:
# ---> 88     translated_text = translate_to_portuguese(text)
#      89     if translated_text:
#      90         print("Translated Text:")
#
# Cell In[18], line 53, in translate_to_portuguese(text)
#      51 elif response.status_code == 429:  # Rate limit exceeded
#      52     print("Rate limit exceeded, retrying...")
# ---> 53     time.sleep(2 ** attempt)  # Exponential backoff
#      54 else:
#      55     print(f"Translation failed for chunk: {response.status_code} - {response.text}")
#
# KeyboardInterrupt:

# %%
import os
import json
import requests
import pdfplumber

# Function to extract text from a PDF and save it to a text file
def extract_text_from_pdf_and_save(pdf_path, output_text_file):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text()

    with open(output_text_file, 'w', encoding='utf-8') as file:
        file.write(text)

# Function to read text from a file
def read_text_from_file(input_text_file):
    with open(input_text_file, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Function to translate text to Portuguese using the local Llama model API
def translate_to_portuguese(text):
    translated_chunks = []
    max_chunk_size = 5000  # Adjust based on the model's capabilities
    text_chunks = [text[i:i + max_chunk_size] for i in range(0, len(text), max_chunk_size)]

    for chunk in text_chunks:
        api_request_json = {
            "model": "llama3.2",
            "messages": [
                {"role": "user", "content": f"Translate the following text to Portuguese: {chunk}"},
            ],
        }

        print(f"Sending request: {json.dumps(api_request_json, indent=2)}")

        response = requests.post("http://localhost:11434/api/chat", json=api_request_json)
        print(f"Response status code: {response.status_code}")
        print(f"Response content: {response.content}")

        if response.status_code == 200:
            try:
                # Attempt to parse the JSON response
                response_json = response.json()
                print(f"Response JSON: {json.dumps(response_json, indent=2)}")
                if "choices" in response_json and len(response_json["choices"]) > 0:
                    translation = response_json["choices"][0]["message"]["content"]
                    translated_chunks.append(translation)  # Store the translated chunk
                else:
                    print("Unexpected response structure:", response_json)
                    return None
            except json.JSONDecodeError as e:
                print(f"JSONDecodeError: {e}")
                return None
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

    return ' '.join(translated_chunks).strip()  # Concatenate and return the complete translated text

# Function to save translated text to a file
def save_translated_text(translated_text, output_file):
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(translated_text)

# Function to extract images from a PDF
def extract_images_from_pdf(pdf_path, output_folder):
    os.makedirs(output_folder, exist_ok=True)

    with pdfplumber.open(pdf_path) as pdf_document:
        for page_number, page in enumerate(pdf_document.pages):
            images = page.images

            for img_index, img in enumerate(images):
                image_bytes = img["stream"].get_data()
                image_ext = img["ext"]
                image_filename = f"page_{page_number + 1}_img_{img_index + 1}.{image_ext}"

                with open(os.path.join(output_folder, image_filename), "wb") as image_file:
                    image_file.write(image_bytes)

# Main function
def main():
    pdf_path = r'C:\Users\carli\OneDrive\Documents\VA.pdf'  # Update your PDF path here
    output_folder = r'C:\Users\carli\OneDrive\Documents\ExtractedImages'  # Output folder for images
    extracted_text_file = r'C:\Users\carli\OneDrive\Documents\ExtractedText.txt'  # Output file for extracted text
    translated_text_file = r'C:\Users\carli\OneDrive\Documents\TranslatedText.txt'  # Output file for translated text

    # Extract text from PDF and save to a text file
    extract_text_from_pdf_and_save(pdf_path, extracted_text_file)
    print(f"Text extracted and saved to {extracted_text_file}")

    # Read the extracted text from the file
    text = read_text_from_file(extracted_text_file)

    if text:
        # Translate the text to Portuguese
        translated_text = translate_to_portuguese(text)
        if translated_text:
            # Save the translated text to a file
            save_translated_text(translated_text, translated_text_file)
            print(f"Translated text saved to {translated_text_file}")
        else:
            print("Translation failed or returned empty text.")
    else:
        print("No text found in the extracted text file.")

    # Extract images from PDF
    extract_images_from_pdf(pdf_path, output_folder)
    print(f"Images extracted to {output_folder}.")

if __name__ == "__main__":
    main()
# Out:
# Text extracted and saved to C:\Users\carli\OneDrive\Documents\ExtractedText.txt
# Sending request: {
#   "model": "llama3.2",
#   "messages": [
#     {
#       "role": "user",
#       "content": "Translate the following text to Portuguese: 2 Vatican AssassinsTitle Page, Copyright, Assassins & Maxims 3\nVatican Assassins:\n\u201cWounded In The House Of My Friends\u201d\nThe Diabolical History of\nThe Society of Jesus\nIncluding:\nIts Second Thirty Years\u2019 War (1914 - 1945),\nIts Cold War (1945 - 1989),\nAnd Its\nAssassination of America\u2019s First\nRoman Catholic President,\nKnight of Columbus\nJohn Fitzgerald Kennedy (1963)\nBy\nEric Jon Phelps\nWhite Separatist American Freeman\nDispensational, Fifth Monarchy, Seventh-Day Baptist-Calvinist4 Vatican Assassins\nVatican Assassins:\n\u201cWounded In The House Of My Friends\u201d\nEric Jon Phelps\nCopyright \u00a9 2001\nSecond Edition: CD/PDF March 2004\nAll rights reserved. Permission is hereby granted to anyone to quote\nFrom VATICAN ASSASSINS: \u201cWounded In The House Of My Friends\u201d,\nin small portions only, for non-commercial use provided there is no\ncontent change, and full credit is given to the author and to the publisher,\nincluding contacting information. To quote larger portions for\ncommercial use, permission from the publisher must be granted in\nadvance. Reproduction of this PDF book, in part or in full, by electronic\nor any other means is strictly prohibited. Use of VATICAN ASSASSINS:\n\u201cWounded In The House Of My Friends\u201d by the film, television, or\ntheater industry, or any other medium, is strictly forbidden unless prior\npermission is granted by the publisher through written contract.\nCategory: Bible/History/Non-Fiction/New (Dark) Age\nSecond Printing: June 2004\nCover design by Norey Latona, Jr.\nEmail: norey@tminet.com\nISBN: 0-9704999-2-2\nPublished by:\nEric Jon Phelps\nP.O. Box 306\nNewmanstown, PA 17073\nwww.vaticanassassins.org\neric@vaticanassassins.orgTitle Page, Copyright, Assassins & Maxims 5\nFrancis Cardinal Spellman, 1946-1967 #1\nArchbishop of New York, 1939-1967\nSurnamed \u201cCardinal War;\u201d\nTrained by the Jesuit Order at Fordham University in New York City;\nand at the Order\u2019s American College in Rome;\nHead of the American Branches of the Knights of Columbus,\nthe Sovereign Military Order of Malta,\nIslamic Shriner Scottish Rite Freemasonry,\nand 33rd Degree Scottish Rite Freemasonry;\n\u201cMilitary Vicar\u201d of the United States Armed Forces;\nMastermind behind the Assassination of President John F. Kennedy\nThe Cardinal Spellman Story, Robert I. Gannon, S.J., (Garden City, New York:\nDoubleday & Company, Inc., 1962).6 Vatican Assassins\nPresident John F. Kennedy and Jackie Kennedy, 1962 #2\nHere we have the President leaving the Jesuit Order\u2019s St. Francis Xavier\nChurch at Hyannis after attending mass. The Chief Executive was\nspending the weekend at the family summer home in nearby Hyannis\nPort. On the far right is Secret Service Agent Roy Kellerman who would\nbe chosen to be the coordinator of the Secret Service\u2019s Assassination Team\nwhile it carried out its \u201cExecutive Action\u201d in Dallas on November 22,\n1963. The President, a Knight of Columbus and son of one of Francis\nCardinal Spellman\u2019s most powerful Knights of Malta \u2013 Joseph P. Kennedy\n\u2013 was educated at Harvard University, with its strong Jesuit presence,\nwhile Jackie gave birth to JFK, Jr., at Georgetown University Hospital.\nAided by the Mafia, the Order had installed its first Irish Roman Catholic\ninto the high office of the American Presidency. But John Kennedy\nturned on the Temporal Power of Rome\u2019s Papal Caesar by refusing to\nenforce the Pope\u2019s claim to rule all the governments of the world.\nKennedy sought to break the power of the Black Pope\u2019s Central\nIntelligence Agency; attacked the Order\u2019s Federal Reserve Bank by\nprinting \u201cUnited States Notes\u201d in lieu of \u201cFederal Reserve Notes;\u201d sought\nto end Cardinal Spellman\u2019s War in Vietnam; and attempted to warn the\nAmerican People of a conspiracy within their CFR-controlled Executive\n ...
#     }
#   ]
# }
# Response status code: 200
# Response content: b'{"model":"llama3.2","created_at":"2024-10-04T00:06:04.7388457Z","message":{"role":"assistant","content":"A"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:04.8544589Z","message":{"role":"assistant","content":"qui"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:04.9645417Z","message":{"role":"assistant","content":" est\xc3\xa1"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.0776406Z","message":{"role":"assistant","content":" o"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.1801838Z","message":{"role":"assistant","content":" texto"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.2847376Z","message":{"role":"assistant","content":" trad"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.3882866Z","message":{"role":"assistant","content":"uz"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.4923377Z","message":{"role":"assistant","content":"ido"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.6019184Z","message":{"role":"assistant","content":" para"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.703959Z","message":{"role":"assistant","content":" o"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.8100202Z","message":{"role":"assistant","content":" port"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:05.9190986Z","message":{"role":"assistant","content":"ugu"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.0236526Z","message":{"role":"assistant","content":"\xc3\xaas"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.1458002Z","message":{"role":"assistant","content":":\\n\\n"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.253369Z","message":{"role":"assistant","content":"2"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.3614422Z","message":{"role":"assistant","content":" Assassin"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.4670014Z","message":{"role":"assistant","content":"atos"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.5811057Z","message":{"role":"assistant","content":" V"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.6826432Z","message":{"role":"assistant","content":"atic"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.7907163Z","message":{"role":"assistant","content":"anos"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.8927567Z","message":{"role":"assistant","content":"\\n\\n"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:06.9937916Z","message":{"role":"assistant","content":"T"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.1134271Z","message":{"role":"assistant","content":"\xc3\xadtulo"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.2114448Z","message":{"role":"assistant","content":","},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.3129823Z","message":{"role":"assistant","content":" Dire"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.4150235Z","message":{"role":"assistant","content":"itos"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.5271169Z","message":{"role":"assistant","content":" Autor"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.6331794Z","message":{"role":"assistant","content":"ais"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.7362253Z","message":{"role":"assistant","content":","},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.8392706Z","message":{"role":"assistant","content":" Assass"},"done":false}\n{"model":"llama3.2","created_at":"2024-10-04T00:06:07.9558897Z","message":{"role":"assistant","content":"inos"},"done":false}\n{"model":"llama3.2","created_a ...
# JSONDecodeError: Extra data: line 2 column 1 (char 123)
# Translation failed or returned empty text.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 114
#     111     print(f"Images extracted to {output_folder}.")
#     113 if __name__ == "__main__":
# --> 114     main()
#
# Cell In[1], line 110, in main()
#     107     print("No text found in the extracted text file.")
#     109 # Extract images from PDF
# --> 110 extract_images_from_pdf(pdf_path, output_folder)
#     111 print(f"Images extracted to {output_folder}.")
#
# Cell In[1], line 77, in extract_images_from_pdf(pdf_path, output_folder)
#      75 for img_index, img in enumerate(images):
#      76     image_bytes = img["stream"].get_data()
# ---> 77     image_ext = img["ext"]
#      78     image_filename = f"page_{page_number + 1}_img_{img_index + 1}.{image_ext}"
#      80     with open(os.path.join(output_folder, image_filename), "wb") as image_file:
#
# KeyError: 'ext'

# %%
import requests
import json
import time

# Replace with your own subscription key and endpoint
subscription_key = 'f0ef490f36bb47e09016d37d204526e6'
endpoint = 'https://api.cognitive.microsofttranslator.com'
location = 'brazilsouth'  # e.g., 'global'

# Read the text file
with open('ExtractedText.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# Function to split text into chunks of a given size
def split_text_into_chunks(text, chunk_size):
    return [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

# Split the text into chunks of 10,000 characters
chunks = split_text_into_chunks(text, 10000)

# Set up the URL for the translation API
url = f'{endpoint}/translate?api-version=3.0&to=pt'  # Translate to Portuguese (Brazil)

# Set up the headers
headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-Type': 'application/json'
}

# Initialize a list to store translated chunks in order
translated_chunks = [None] * len(chunks)

# Function to handle the translation with exponential backoff
def translate_chunk_with_backoff(chunk, max_retries=5, initial_delay=1):
    delay = initial_delay
    for attempt in range(max_retries):
        body = [{
            'text': chunk
        }]

        # Make the request to the translation API
        response = requests.post(url, headers=headers, json=body)

        # Check if the request was successful
        if response.status_code == 200:
            try:
                translations = response.json()
                translated_text = translations[0]['translations'][0]['text']
                return translated_text
            except json.JSONDecodeError:
                print("Error: The response is not in JSON format.")
                print(response.text)
                return None
        elif response.status_code == 429:
            print(f"Rate limit exceeded. Waiting {delay} seconds before retrying...")
            time.sleep(delay)
            delay *= 2  # Exponential backoff
        else:
            print(f"Error: {response.status_code}")
            print(response.text)
            return None
    return None

# Translate each chunk with exponential backoff and retry failed chunks
for index, chunk in enumerate(chunks):
    translated_text = translate_chunk_with_backoff(chunk)
    if translated_text:
        translated_chunks[index] = translated_text
        print(f"Chunk {index + 1}/{len(chunks)} translated successfully.")
    else:
        print(f"Failed to translate chunk {index + 1}/{len(chunks)}. Retrying...")
        retry_attempts = 0
        while translated_text is None and retry_attempts < 5:
            translated_text = translate_chunk_with_backoff(chunk)
            retry_attempts += 1
            if translated_text:
                translated_chunks[index] = translated_text
                print(f"Chunk {index + 1}/{len(chunks)} translated successfully after {retry_attempts} retries.")
            else:
                print(f"Retry {retry_attempts} failed for chunk {index + 1}/{len(chunks)}.")

# Check if any chunks failed to translate
failed_chunks = [index for index, chunk in enumerate(translated_chunks) if chunk is None]
if failed_chunks:
    print(f"Failed to translate chunks: {failed_chunks}")
else:
    # Combine the translated chunks
    translated_text = ''.join(translated_chunks)

    # Save the translated text to a file
    with open('TranslatedText.txt', 'w', encoding='utf-8') as file:
        file.write(translated_text)

    print("Translation complete. The translated text has been saved to 'TranslatedText.txt'.")
# Out:
# Chunk 1/161 translated successfully.
# Chunk 2/161 translated successfully.
# Chunk 3/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 4/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 4/161 translated successfully after 1 retries.
# Chunk 5/161 translated successfully.
# Chunk 6/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 7/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 7/161 translated successfully after 1 retries.
# Chunk 8/161 translated successfully.
# Chunk 9/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 10/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 10/161.
# Chunk 10/161 translated successfully after 2 retries.
# Chunk 11/161 translated successfully.
# Chunk 12/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 13/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 13/161 translated successfully after 1 retries.
# Chunk 14/161 translated successfully.
# Chunk 15/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 16/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 16/161 translated successfully after 1 retries.
# Chunk 17/161 translated successfully.
# Chunk 18/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 19/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 19/161.
# Chunk 19/161 translated successfully after 2 retries.
# Chunk 20/161 translated successfully.
# Chunk 21/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 22/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 22/161 translated successfully after 1 retries.
# Chunk 23/161 translated successfully.
# Chunk 24/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 25/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 25/161 translated successfully after 1 retries.
# Chunk 26/161 translated successfully.
# Chunk 27/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 28/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 28/161.
# Chunk 28/161 translated successfully after 2 retries.
# Chunk 29/161 translated successfully.
# Chunk 30/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 31/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 31/161 translated successfully after 1 retries.
# Chunk 32/161 translated successfully.
# Chunk 33/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 34/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 34/161.
# Chunk 34/161 translated successfully after 2 retries.
# Chunk 35/161 translated successfully.
# Chunk 36/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 37/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 37/161 translated successfully after 1 retries.
# Chunk 38/161 translated successfully.
# Chunk 39/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 40/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 40/161.
# Chunk 40/161 translated successfully after 2 retries.
# Chunk 41/161 translated successfully.
# Chunk 42/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 43/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 43/161 translated successfully after 1 retries.
# Chunk 44/161 translated successfully.
# Chunk 45/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 46/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 46/161.
# Chunk 46/161 translated successfully after 2 retries.
# Chunk 47/161 translated successfully.
# Chunk 48/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 49/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 49/161 translated successfully after 1 retries.
# Chunk 50/161 translated successfully.
# Chunk 51/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 52/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 52/161 translated successfully after 1 retries.
# Chunk 53/161 translated successfully.
# Chunk 54/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 55/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 55/161.
# Chunk 55/161 translated successfully after 2 retries.
# Chunk 56/161 translated successfully.
# Chunk 57/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 58/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 58/161 translated successfully after 1 retries.
# Chunk 59/161 translated successfully.
# Chunk 60/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 61/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 61/161.
# Chunk 61/161 translated successfully after 2 retries.
# Chunk 62/161 translated successfully.
# Chunk 63/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 64/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 64/161 translated successfully after 1 retries.
# Chunk 65/161 translated successfully.
# Chunk 66/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 67/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 67/161.
# Chunk 67/161 translated successfully after 2 retries.
# Chunk 68/161 translated successfully.
# Chunk 69/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 70/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 70/161 translated successfully after 1 retries.
# Chunk 71/161 translated successfully.
# Chunk 72/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 73/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 73/161 translated successfully after 1 retries.
# Chunk 74/161 translated successfully.
# Chunk 75/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 76/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 76/161.
# Chunk 76/161 translated successfully after 2 retries.
# Chunk 77/161 translated successfully.
# Chunk 78/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 79/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 79/161 translated successfully after 1 retries.
# Chunk 80/161 translated successfully.
# Chunk 81/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 82/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 82/161 translated successfully after 1 retries.
# Chunk 83/161 translated successfully.
# Chunk 84/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 85/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 85/161.
# Chunk 85/161 translated successfully after 2 retries.
# Chunk 86/161 translated successfully.
# Chunk 87/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 88/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 88/161 translated successfully after 1 retries.
# Chunk 89/161 translated successfully.
# Chunk 90/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 91/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 91/161.
# Chunk 91/161 translated successfully after 2 retries.
# Chunk 92/161 translated successfully.
# Chunk 93/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 94/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 94/161 translated successfully after 1 retries.
# Chunk 95/161 translated successfully.
# Chunk 96/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 97/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 97/161.
# Chunk 97/161 translated successfully after 2 retries.
# Chunk 98/161 translated successfully.
# Chunk 99/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 100/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 100/161 translated successfully after 1 retries.
# Chunk 101/161 translated successfully.
# Chunk 102/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 103/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 103/161.
# Chunk 103/161 translated successfully after 2 retries.
# Chunk 104/161 translated successfully.
# Chunk 105/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 106/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 106/161 translated successfully after 1 retries.
# Chunk 107/161 translated successfully.
# Chunk 108/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 109/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 109/161 translated successfully after 1 retries.
# Chunk 110/161 translated successfully.
# Chunk 111/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 112/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 112/161.
# Chunk 112/161 translated successfully after 2 retries.
# Chunk 113/161 translated successfully.
# Chunk 114/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 115/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 115/161 translated successfully after 1 retries.
# Chunk 116/161 translated successfully.
# Chunk 117/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 118/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 118/161 translated successfully after 1 retries.
# Chunk 119/161 translated successfully.
# Chunk 120/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 121/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 121/161.
# Chunk 121/161 translated successfully after 2 retries.
# Chunk 122/161 translated successfully.
# Chunk 123/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 124/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Chunk 124/161 translated successfully after 1 retries.
# Chunk 125/161 translated successfully.
# Chunk 126/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 127/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 127/161.
# Chunk 127/161 translated successfully after 2 retries.
# Chunk 128/161 translated successfully.
# Chunk 129/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 130/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 130/161 translated successfully after 1 retries.
# Chunk 131/161 translated successfully.
# Chunk 132/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 133/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 133/161 translated successfully after 1 retries.
# Chunk 134/161 translated successfully.
# Chunk 135/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 136/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 136/161.
# Chunk 136/161 translated successfully after 2 retries.
# Chunk 137/161 translated successfully.
# Chunk 138/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 139/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 139/161 translated successfully after 1 retries.
# Chunk 140/161 translated successfully.
# Chunk 141/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 142/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 142/161 translated successfully after 1 retries.
# Chunk 143/161 translated successfully.
# Chunk 144/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 145/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 145/161.
# Chunk 145/161 translated successfully after 2 retries.
# Chunk 146/161 translated successfully.
# Chunk 147/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 148/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 148/161 translated successfully after 1 retries.
# Chunk 149/161 translated successfully.
# Chunk 150/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 151/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 151/161 translated successfully after 1 retries.
# Chunk 152/161 translated successfully.
# Chunk 153/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 154/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Retry 1 failed for chunk 154/161.
# Chunk 154/161 translated successfully after 2 retries.
# Chunk 155/161 translated successfully.
# Chunk 156/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 157/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 157/161 translated successfully after 1 retries.
# Chunk 158/161 translated successfully.
# Chunk 159/161 translated successfully.
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Rate limit exceeded. Waiting 16 seconds before retrying...
# Failed to translate chunk 160/161. Retrying...
# Rate limit exceeded. Waiting 1 seconds before retrying...
# Rate limit exceeded. Waiting 2 seconds before retrying...
# Rate limit exceeded. Waiting 4 seconds before retrying...
# Rate limit exceeded. Waiting 8 seconds before retrying...
# Chunk 160/161 translated successfully after 1 retries.
# Chunk 161/161 translated successfully.
# Translation complete. The translated text has been saved to 'TranslatedText.txt'.
